# %% [markdown]
# <a href="https://colab.research.google.com/github/shivangirautela/oyesters_training_cum_internship/blob/master/assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a Program to plot a graph for an analysis of a cricket match . Over a period of 20 overs starting from 2nd over to 20th over, the visualisation graph has to be created for Team1 as well as Team2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(2.5,22.5,2.5)
print(x)
y1=np.random.randint(0,300,8)
print(y1)
y2=np.random.randint(0,300,8)
print(y2)
plt.plot(x,y1,c='r',marker='*')
plt.plot(x,y2,c='g',marker='*')
plt.xlabel("overs")
plt.ylabel("runs")
plt.title("analysis of cricket match")
# Out:
# [ 2.5  5.   7.5 10.  12.5 15.  17.5 20. ]
# [233 202 279 196 180  31 243 277]
# [138 134  13  88 172 207 165 229]
# Text(0.5, 1.0, 'analysis of cricket match')

# %%
overs=np.arange(2,21,3)
overs
# Out:
# array([ 2,  5,  8, 11, 14, 17, 20])

# %%
team1=np.random.randint(0,150,7)
team2=np.random.randint(0,150,7)
team1=np.sort(team1)
team2=np.sort(team2)
print(team1)
print(team2)
# Out:
# [ 16  30  38  72  87 108 123]
# [ 23  33  40  85  95 113 117]

# %%
plt.plot(overs,team1,marker="*",c='r',label='Team1')
plt.plot(overs,team2,marker="*",c='g',label='Team2')
plt.xlabel('overs')
plt.ylabel('runs')
plt.title("analysis of cricket match")
plt.legend()

# %% [markdown]
# Create a list named mobile_count which contains 5 random values from range of 0 to 100. Use for loop and random library
#
# Use a variable named mobile _model as Apple,Samsung,Vivo,Nokia and Huawei
#
# Plot a Pie chart for mobile_count variable and consider mobile _model as a labels parameter

# %%
import random   #importing random library
mobile_count=[]  #initializing empty list
for i in range(5):  
  x = np.random.randint(0,100)
  mobile_count.append(x)
print(mobile_count)
# Out:
# [92, 53, 53, 97, 70]

# %%
import matplotlib.pyplot as plt
mobile_model= [ 'Apple','Samsung','Vivo','Nokia' , 'Huawei']
plt.pie(mobile_count, labels = mobile_model)
plt.show()
